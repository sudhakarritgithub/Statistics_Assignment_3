# %% [raw]
#                                                                                      STATISTICS ASSIGNMENT - 3

# %% [raw]
# Ques.1 What is the Probability density function?

# %% [raw]
# The Probability Density Function (PDF) is a concept in probability theory and statistics that describes the likelihood of a continuous random variable taking on a particular value. Here are the key points about the PDF:
# Definition: For a continuous random variable 𝑋, the PDF, denoted as 𝑓(𝑥), is a function that assigns probabilities to each possible outcome within a certain range. Unlike discrete random variables, which             have probability mass functions (PMFs), continuous random variables have PDFs because they can take on an infinite number of values within a range.
# Properties:The PDF f(x) must be non-negative for all x. The total area under the PDF curve over its entire range must equal 1, representing the total probability that the random variable X takes on some              value within that range.

# %% [raw]
# Ques.2 What are the types of Probability distribution?

# %% [raw]
# Probability distributions are categorized into two main types based on the nature of the random variable they describe: discrete and continuous distributions.
#
# 1. Discrete Probability Distributions:
#
# Bernoulli Distribution: Models a single trial with two outcomes (success/failure).
# Binomial Distribution: Describes the number of successes in a fixed number of independent Bernoulli trials.
# Poisson Distribution: Models the number of events occurring in a fixed interval of time or space, given a known average rate of occurrence.
# Continuous Probability Distributions:
#
# 2.Uniform Distribution: All outcomes in an interval are equally likely.
# Normal Distribution (Gaussian Distribution): Characterized by a bell-shaped curve and is defined by its mean and standard deviation.
# Exponential Distribution: Models the time between events in a Poisson process (events occur continuously and independently at a constant average rate).
# Gamma Distribution: Generalizes the exponential distribution to include a shape parameter.
# Beta Distribution: Describes probabilities of outcomes bounded by 0 and 1, often used in Bayesian statistics.
#
# These distributions serve as fundamental models for various real-world phenomena and are used extensively in statistical inference, modeling, and hypothesis testing. Each type of distribution has its own unique properties, which make them suitable for different types of data and applications in probability theory and statistics.

# %% [raw]
# Ques.3  Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
import math

def normal_pdf(x, mean, std_dev):
    """
    Calculate the probability density function (PDF) of a normal distribution at point x.

    Parameters:
    - x (float): The point at which to evaluate the PDF.
    - mean (float): Mean of the normal distribution.
    - std_dev (float): Standard deviation of the normal distribution.

    Returns:
    - float: PDF value at point x.
    """
    exponent = -((x - mean)**2) / (2 * std_dev**2)
    coefficient = 1 / (std_dev * math.sqrt(2 * math.pi))
    pdf_value = coefficient * math.exp(exponent)
    return pdf_value

# Example usage:
mean = 0
std_dev = 1
x = 1.5
pdf_at_x = normal_pdf(x, mean, std_dev)
print(f"PDF at x = {x}: {pdf_at_x}")
# Out:
# PDF at x = 1.5: 0.12951759566589174

# %% [raw]
# Ques.4 What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [raw]
# The Binomial distribution is characterized by the following properties:
#
# Fixed Number of Trials: The distribution models a fixed number n of independent trials.
# Two Possible Outcomes: Each trial results in one of two outcomes, often referred to as "success" and "failure".
# Constant Probability: The probability of success 𝑝 remains constant across all trials.
# Discrete Nature: The random variable X, representing the number of successes in n trials, is discrete.
# Parameters: The distribution is defined by two parameters:
# n: The number of trials.
# p: The probability of success on each trial.
#
# Examples of Events Where Binomial Distribution Can Be Applied:
#
# Example 1: Coin Flips
# Scenario: Suppose you flip a fair coin (where the probability of getting heads, p, is 0.5) 10 times.
# Binomial Distribution Application: The number of heads obtained in these 10 flips follows a Binomial distribution with parameters n=10 and p=0.5.
# Use: This can be used to calculate probabilities like "What is the probability of getting exactly 5 heads out of 10 flips?".
#
# Example 2: Product Defects
# Scenario: A factory produces light bulbs, and historically 5% of the bulbs are defective.
# Binomial Distribution Application: If you randomly select 20 bulbs from the production line, the number of defective bulbs among these 20 follows a Binomial distribution with parameters n=20 and p=0.05.
# Use: This distribution can be used to determine probabilities such as "What is the probability that fewer than 3 bulbs are defective?".

# %% [raw]
# Ques.5  Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 20   # Number of trials
p = 0.4  # Probability of success

# Generate random sample of size 1000 from Binomial distribution
sample = np.random.binomial(n, p, size=1000)

# Plotting histogram
plt.figure(figsize=(8, 6))
plt.hist(sample, bins=np.arange(0, n+2)-0.5, density=True, edgecolor='black')  # bins for discrete values
plt.xticks(np.arange(0, n+1))
plt.xlabel('Number of Successes')
plt.ylabel('Probability Density')
plt.title(f'Binomial Distribution: n={n}, p={p}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [raw]
# Ques.6 Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
import math

def poisson_cdf(k, mean):
    """
    Calculate the cumulative distribution function (CDF) of a Poisson distribution at point k.

    Parameters:
    - k (int): The point at which to evaluate the CDF.
    - mean (float): Mean (lambda) of the Poisson distribution.

    Returns:
    - float: CDF value at point k.
    """
    cdf = 0.0
    for i in range(k + 1):
        cdf += math.exp(-mean) * (mean**i) / math.factorial(i)
    return cdf

# Example usage:
mean = 2.5
k = 3
cdf_at_k = poisson_cdf(k, mean)
print(f"CDF at k = {k}: {cdf_at_k}")
# Out:
# CDF at k = 3: 0.7575761331330659

# %% [raw]
# Ques.7 . How Binomial distribution different from Poisson distribution?

# %% [raw]
# Differences:
#
# Nature of Trials/Events: Binomial distribution is used when there is a fixed number of trials or experiments, each with a binary outcome (success/failure), whereas Poisson distribution is used to model                            the number of occurrences of events in a continuous interval of time or space.
# Parameters: Binomial distribution has two parameters (n and p), whereas Poisson distribution has one parameter (λ).
# Assumptions: Binomial distribution assumes a fixed number of trials and a constant probability of success on each trial, while Poisson distribution assumes events occur independently at a constant average              rate.
# Applications: Binomial distribution is often used in scenarios involving a fixed number of trials or experiments with binary outcomes, while Poisson distribution is used in scenarios involving counts of                 events over a continuous interval.

# %% [raw]
# Ques.8 Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance

# %%
import numpy as np

# Parameters
mean = 5  # Mean (lambda) of the Poisson distribution
sample_size = 1000  # Size of the random sample

# Generate random sample from Poisson distribution
sample = np.random.poisson(mean, size=sample_size)

# Calculate sample mean and variance
sample_mean = np.mean(sample)
sample_variance = np.var(sample)

# Print results
print(f"Sample Mean: {sample_mean}")
print(f"Sample Variance: {sample_variance}")
# Out:
# Sample Mean: 4.93
# Sample Variance: 4.9511

# %% [raw]
# Ques.9  How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [raw]
# Binomial Distribution: The variance 𝜎2 depends on both n (number of trials) and p (probability of success), and their interplay determines the spread of the distribution.
#
# Poisson Distribution: The variance σ2 is solely determined by the mean λ, indicating that in Poisson processes, the variability (variance) is directly tied to the rate (mean) at which events occur.
#
# In summary, while both mean and variance are measures of central tendency and dispersion respectively, in the Binomial distribution they are linked by the product n⋅p⋅(1−p), whereas in the Poisson distribution they are directly equal, reflecting the deterministic nature of the variability around the mean in Poisson processes.

# %%
Q
